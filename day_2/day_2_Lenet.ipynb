# %%
import numpy as np
import matplotlib.pyplot as plt

import torch
import torchvision
import torch.nn as nn
import torch.nn.functional as F
import torchvision.transforms as transforms

# %%
class LeNet(nn.Module):

    def __init__(self):
        super(LeNet, self).__init__()
        # 3 input image channel, 6 output feature maps and 5x5 conv kernel
        self.cn1 = nn.Conv2d(3, 6, 5)
        # 6 input image channel, 16 output feature maps and 5x5 conv kernel
        self.cn2 = nn.Conv2d(6, 16, 5)
        # fully connected layers of size 120, 84 and 10
        self.fc1 = nn.Linear(16 * 5 * 5, 120)  # 5*5 is the spatial dimension at this layer
        self.fc2 = nn.Linear(120, 84)
        self.fc3 = nn.Linear(84, 10)

    def forward(self, x):
        # Convolution with 5x5 kernel
        x = F.relu(self.cn1(x))
        # Max pooling over a (2, 2) window
        x = F.max_pool2d(x, (2, 2))
        # Convolution with 5x5 kernel
        x = F.relu(self.cn2(x))
        # Max pooling over a (2, 2) window
        x = F.max_pool2d(x, (2, 2))
        # Flatten spatial and depth dimensions into a single vector
        x = x.view(-1, self.flattened_features(x))
        # Fully connected operations
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x

    def flattened_features(self, x):
        # all except the first (batch) dimension
        size = x.size()[1:]
        num_feats = 1
        for s in size:
            num_feats *= s
        return num_feats


lenet = LeNet()
print(lenet)
# Out:
# LeNet(
#   (cn1): Conv2d(3, 6, kernel_size=(5, 5), stride=(1, 1))
#   (cn2): Conv2d(6, 16, kernel_size=(5, 5), stride=(1, 1))
#   (fc1): Linear(in_features=400, out_features=120, bias=True)
#   (fc2): Linear(in_features=120, out_features=84, bias=True)
#   (fc3): Linear(in_features=84, out_features=10, bias=True)
# )

# %% [markdown]
# Training the LeNEt model

# %%
def train(net, trainloader, optim, epoch):
    # initialize loss
    loss_total = 0.0

    for i, data in enumerate(trainloader, 0):
        # get the inputs; data is a list of [inputs, labels]
        # ip refers to the input images, and ground_truth refers to the output classes the images belong to
        ip, ground_truth = data

        # zero the parameter gradients
        optim.zero_grad()

        # forward pass + backward pass + optimization step
        op = net(ip)
        loss = nn.CrossEntropyLoss()(op, ground_truth)
        loss.backward()
        optim.step()

        # update loss
        loss_total += loss.item()

        # print loss statistics
        if (i+1) % 1000 == 0:    # print at the interval of 1000 mini-batches
            print('[Epoch number : %d, Mini-batches: %5d] loss: %.3f' %
                  (epoch + 1, i + 1, loss_total / 200))
            loss_total = 0.0

# %%
def test(net,testLoader):
  success=0
  counter=0
  with torch.no_grad():
    for data in testLoader:
      images,labels=data
      outputs=net(images)
      print("output predicted is :" ,outputs)
      _,predicted=torch.max(outputs.data,1)
      counter+=labels.size(0)
      success+=(predicted==labels).sum().item()
  print('LeNet accuracy on 10000 images from test dataset: %d %%' % (
        100 * success / counter))

# %%
# The mean and std are kept as 0.5 for normalizing pixel values as the pixel values are originally in the range 0 to 1
train_transform = transforms.Compose([transforms.RandomHorizontalFlip(),
                                      transforms.RandomCrop(32, 4),
                                      transforms.ToTensor(),
                                      transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

trainset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=train_transform)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=8, shuffle=True)


test_transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

testset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=test_transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=10000, shuffle=False)


# ordering is important
classes = ('plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck')
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
# define a function that displays an image
def imageshow(image):
    # un-normalize the image
    image = image/2 + 0.5
    npimage = image.numpy()
    plt.imshow(np.transpose(npimage, (1, 2, 0)))
    plt.show()


# sample images from training set
dataiter = iter(trainloader)
images, labels = next(dataiter)

# display images in a grid
num_images = 4
imageshow(torchvision.utils.make_grid(images[:num_images]))
# print labels
print('    '+'  ||  '.join(classes[labels[j]] for j in range(num_images)))
# Out:
#     deer  ||  cat  ||  deer  ||  ship

# %%
# define optimizer
optim = torch.optim.Adam(lenet.parameters(), lr=0.001)

# training loop over the dataset multiple times
for epoch in range(50):
    train(lenet, trainloader, optim, epoch)
    print()
    test(lenet, testloader)
    print()

print('Finished Training')
# Out:
# [Epoch number : 1, Mini-batches:  1000] loss: 9.798
# [Epoch number : 1, Mini-batches:  2000] loss: 8.711
# [Epoch number : 1, Mini-batches:  3000] loss: 8.216
# [Epoch number : 1, Mini-batches:  4000] loss: 8.063
# [Epoch number : 1, Mini-batches:  5000] loss: 7.822
# [Epoch number : 1, Mini-batches:  6000] loss: 7.721
#
# output predicted is : tensor([[-1.3828, -1.7660, -0.2076,  ..., -1.5304, -1.4964, -1.7303],
#         [ 1.9549,  3.3710, -1.6400,  ..., -3.9846,  3.5577,  0.9645],
#         [ 1.1472,  1.7639, -0.7750,  ..., -3.1433,  2.4187,  0.4067],
#         ...,
#         [-2.2445, -4.9931, -0.4902,  ...,  0.0848, -3.3542, -3.5554],
#         [-0.2666, -0.5064,  0.0077,  ...,  0.4742, -1.4186, -0.2446],
#         [-1.9149, -2.4635, -0.4741,  ...,  1.2257, -3.0921, -1.5600]])
# LeNet accuracy on 10000 images from test dataset: 48 %
#
# [Epoch number : 2, Mini-batches:  1000] loss: 7.613
# [Epoch number : 2, Mini-batches:  2000] loss: 7.392
# [Epoch number : 2, Mini-batches:  3000] loss: 7.330
# [Epoch number : 2, Mini-batches:  4000] loss: 7.275
# [Epoch number : 2, Mini-batches:  5000] loss: 7.300
# [Epoch number : 2, Mini-batches:  6000] loss: 7.150
#
# output predicted is : tensor([[-2.6306, -2.3951, -0.7229,  ..., -1.4971, -2.4561, -3.6743],
#         [ 2.6511,  5.9218, -4.2004,  ..., -4.3751,  2.2670,  2.9854],
#         [ 1.3330,  1.7571, -1.8419,  ..., -3.0475,  2.4980,  0.3385],
#         ...,
#         [-3.2515, -5.0328, -0.3903,  ...,  1.1147, -5.1949, -3.4488],
#         [ 0.0088,  0.1162,  0.0112,  ...,  0.3306, -2.2119, -0.2749],
#         [-3.5694, -4.2549, -0.5314,  ...,  3.5607, -5.7687, -2.8566]])
# LeNet accuracy on 10000 images from test dataset: 48 %
#
# [Epoch number : 3, Mini-batches:  1000] loss: 6.905
# [Epoch number : 3, Mini-batches:  2000] loss: 6.987
# [Epoch number : 3, Mini-batches:  3000] loss: 6.892
# [Epoch number : 3, Mini-batches:  4000] loss: 6.879
# [Epoch number : 3, Mini-batches:  5000] loss: 6.937
# [Epoch number : 3, Mini-batches:  6000] loss: 6.846
#
# output predicted is : tensor([[-2.1727, -4.5456, -0.7618,  ..., -2.1093, -1.0252, -4.6225],
#         [ 1.8817,  3.7651, -4.3169,  ..., -5.5175,  2.6933,  1.9078],
#         [ 1.7722,  0.7938, -1.5654,  ..., -2.9496,  1.7542,  0.6142],
#         ...,
#         [-2.9826, -5.7602, -0.4692,  ...,  0.1443, -3.2948, -4.3665],
#         [ 0.1261,  0.5242,  0.3234,  ..., -0.5549, -2.3316, -0.1926],
#         [-3.5909, -5.2366, -1.1704,  ...,  4.1503, -6.5308, -3.3821]])
# LeNet accuracy on 10000 images from test dataset: 54 %
#
# [Epoch number : 4, Mini-batches:  1000] loss: 6.780
# [Epoch number : 4, Mini-batches:  2000] loss: 6.643
# [Epoch number : 4, Mini-batches:  3000] loss: 6.632
# [Epoch number : 4, Mini-batches:  4000] loss: 6.645
# [Epoch number : 4, Mini-batches:  5000] loss: 6.597
# [Epoch number : 4, Mini-batches:  6000] loss: 6.608
#
# output predicted is : tensor([[-2.9293, -3.4734, -2.0374,  ..., -0.5824, -1.9723, -3.9509],
#         [ 1.8600,  3.6463, -4.1907,  ..., -4.9971,  3.4863,  0.7424],
#         [ 1.3519,  0.6813, -0.9209,  ..., -2.2676,  1.2328,  0.1740],
#         ...,
#         [-2.6474, -6.9973, -1.3841,  ...,  0.7546, -2.9378, -4.1052],
#         [-0.5516, -0.5356,  0.3299,  ...,  0.2709, -2.3276, -0.8079],
#         [-4.2103, -5.0293, -1.4692,  ...,  3.7911, -7.4314, -4.6325]])
# LeNet accuracy on 10000 images from test dataset: 54 %
#
# [Epoch number : 5, Mini-batches:  1000] loss: 6.538
# [Epoch number : 5, Mini-batches:  2000] loss: 6.519
# [Epoch number : 5, Mini-batches:  3000] loss: 6.481
# [Epoch number : 5, Mini-batches:  4000] loss: 6.384
# [Epoch number : 5, Mini-batches:  5000] loss: 6.349
# [Epoch number : 5, Mini-batches:  6000] loss: 6.449
#
# output predicted is : tensor([[-2.9817, -5.3269, -2.0957,  ..., -1.8472, -2.9905, -3.2332],
#         [ 2.0029,  3.1109, -4.6403,  ..., -8.1396,  5.8750, -0.1032],
#         [ 1.5710,  0.0884, -1.0752,  ..., -3.1150,  1.6568, -0.2078],
#         ...,
#         [-3.6813, -6.3576, -1.8264,  ...,  0.2508, -2.9932, -4.2002],
#         [ 0.3703, -0.3231, -0.2425,  ..., -0.5954, -2.4546, -0.8715],
#         [-2.9721, -4.2645, -0.6120,  ...,  3.2255, -7.1294, -4.0150]])
# LeNet accuracy on 10000 images from test dataset: 56 %
#
# [Epoch number : 6, Mini-batches:  1000] loss: 6.273
# [Epoch number : 6, Mini-batches:  2000] loss: 6.346
# [Epoch number : 6, Mini-batches:  3000] loss: 6.314
# [Epoch number : 6, Mini-batches:  4000] loss: 6.289
# [Epoch number : 6, Mini-batches:  5000] loss: 6.294
# [Epoch number : 6, Mini-batches:  6000] loss: 6.257
#
# output predicted is : tensor([[ -2.3595,  -3.2671,  -2.0655,  ...,  -1.3828,  -1.7122,  -2.7666],
#         [  0.8667,   1.0083,  -5.4269,  ...,  -6.7135,   4.7244,  -1.0256],
#         [  0.5727,  -0.2273,  -1.0705,  ...,  -1.5337,   1.8743,  -1.0512],
#         ...,
#         [ -4.2180,  -6.3455,  -1.6804,  ...,  -0.0172,  -4.4335,  -4.1442],
#         [  0.4208,  -0.1659,  -0.4981,  ...,  -0.0779,  -1.4220,  -1.3433],
#         [ -5.2393,  -6.4322,  -1.9532,  ...,   4.7095, -10.5909,  -6.4147]])
# LeNet accuracy on 10000 images from test dataset: 57 %
#
# [Epoch number : 7, Mini-batches:  1000] loss: 6.208
# [Epoch number : 7, Mini-batches:  2000] loss: 6.200
# [Epoch number : 7, Mini-batches:  3000] loss: 6.194
# [Epoch number : 7, Mini-batches:  4000] loss: 6.172
# [Epoch number : 7, Mini-batches:  5000] loss: 6.151
# [Epoch number : 7, Mini-batches:  6000] loss: 6.130
#
# output predicted is : tensor([[-3.0503, -4.0613, -1.3778,  ..., -1.2244, -2.5762, -3.0890],
#         [ 0.3812,  3.4351, -4.6472,  ..., -8.0048,  5.3536, -0.3714],
#         [ 1.0954,  0.0944, -1.3728,  ..., -2.5908,  2.3955, -0.1519],
#         ...,
#         [-4.1956, -5.7365, -1.6775,  ..., -0.0474, -4.5747, -3.2473],
#         [-0.4300,  0.0336, -0.2140,  ..., -0.0143, -2.5499, -1.0149],
#         [-4.8502, -6.7446, -1.1181,  ...,  4.7671, -9.2371, -5.7504]])
# LeNet accuracy on 10000 images from test dataset: 60 %
#
# [Epoch number : 8, Mini-batches:  1000] loss: 6.031
# [Epoch number : 8, Mini-batches:  2000] loss: 6.221
# [Epoch number : 8, Mini-batches:  3000] loss: 6.186
# [Epoch number : 8, Mini-batches:  4000] loss: 6.172
# [Epoch number : 8, Mini-batches:  5000] loss: 6.009
# [Epoch number : 8, Mini-batches:  6000] loss: 5.937
#
# output predicted is : tensor([[-2.1706, -3.5221, -1.1170,  ..., -1.8251, -2.1100, -2.8168],
#         [ 0.6282,  4.2815, -4.9132,  ..., -8.6833,  3.2717, -0.4778],
#         [ 0.2238,  0.2726, -1.9617,  ..., -2.8326,  1.5726,  0.7295],
#         ...,
#         [-4.3910, -7.1540, -0.1660,  ..., -0.8015, -5.4111, -4.0850],
#         [ 1.1680, -0.5623, -0.3267,  ..., -0.7769, -2.9747, -1.9638],
#         [-3.2540, -7.7381, -1.6274,  ...,  5.3093, -7.2090, -5.0722]])
# LeNet accuracy on 10000 images from test dataset: 59 %
#
# [Epoch number : 9, Mini-batches:  1000] loss: 6.080
# [Epoch number : 9, Mini-batches:  2000] loss: 6.002
# [Epoch number : 9, Mini-batches:  3000] loss: 5.983
# [Epoch number : 9, Mini-batches:  4000] loss: 5.898
# [Epoch number : 9, Mini-batches:  5000] loss: 6.051
# [Epoch number : 9, Mini-batches:  6000] loss: 5.996
#
# output predicted is : tensor([[-2.9035e+00, -5.3233e+00, -1.7564e+00,  ..., -2.1304e+00,
#          -3.1412e+00, -3.9441e+00],
#         [ 5.4441e-01,  2.0066e+00, -6.1529e+00,  ..., -1.0671e+01,
#           2.9421e+00, -1.3774e+00],
#         [ 2.3096e-01,  2.9176e-03, -2.2774e+00,  ..., -3.2354e+00,
#           1.9330e+00,  6.0018e-01],
#         ...,
#         [-4.2071e+00, -7.2625e+00, -2.1691e+00,  ..., -1.0737e+00,
#          -4.9026e+00, -5.2845e+00],
#         [-2.6000e-01, -2.0888e-01, -8.2959e-01,  ...,  7.8101e-01,
#          -9.1769e-01, -1.7155e-01],
#         [-4.4075e+00, -7.6621e+00, -2.2894e+00,  ...,  4.0759e+00,
#          -7.7681e+00, -6.3866e+00]])
# LeNet accuracy on 10000 images from test dataset: 61 %
#
# [Epoch number : 10, Mini-batches:  1000] loss: 5.941
# [Epoch number : 10, Mini-batches:  2000] loss: 5.853
# [Epoch number : 10, Mini-batches:  3000] loss: 5.973
# [Epoch number : 10, Mini-batches:  4000] loss: 6.000
# [Epoch number : 10, Mini-batches:  5000] loss: 5.874
# [Epoch number : 10, Mini-batches:  6000] loss: 5.939
#
# output predicted is : tensor([[-2.8616, -3.9988, -2.2631,  ..., -2.6099, -2.9186, -3.2800],
#         [ 0.0418,  2.3614, -3.6156,  ..., -6.2284,  2.7572, -1.6913],
#         [ 0.1863,  0.3447, -1.6179,  ..., -2.8698,  1.4275,  0.2816],
#         ...,
#         [-4.5572, -5.8505, -1.0409,  ..., -0.8127, -4.6413, -4.8903],
#         [-0.0808,  1.8660, -0.4017,  ..., -1.3503, -1.1421,  0.8275],
#         [-2.0699, -3.6190, -0.6803,  ...,  2.8250, -3.4964, -4.2534]])
# LeNet accuracy on 10000 images from test dataset: 60 %
#
# [Epoch number : 11, Mini-batches:  1000] loss: 5.932
# [Epoch number : 11, Mini-batches:  2000] loss: 5.758
# [Epoch number : 11, Mini-batches:  3000] loss: 5.936
# [Epoch number : 11, Mini-batches:  4000] loss: 5.811
# [Epoch number : 11, Mini-batches:  5000] loss: 5.918
# [Epoch number : 11, Mini-batches:  6000] loss: 5.962
#
# output predicted is : tensor([[-2.3962, -3.4738, -1.4393,  ..., -1.8017, -2.1783, -3.3804],
#         [ 1.1065,  3.1222, -4.9400,  ..., -6.7724,  3.3737, -0.2234],
#         [-0.0721,  0.5113, -2.2954,  ..., -2.7006,  0.5371,  1.4583],
#         ...,
#         [-4.8494, -9.1656, -1.8258,  ..., -1.4471, -6.9585, -8.5206],
#         [-0.4379,  1.8543, -0.7576,  ..., -1.1566, -2.6404, -1.5240],
#         [-4.9567, -6.8508, -0.6847,  ...,  5.3706, -8.5137, -7.6020]])
# LeNet accuracy on 10000 images from test dataset: 61 %
#
# [Epoch number : 12, Mini-batches:  1000] loss: 5.902
# [Epoch number : 12, Mini-batches:  2000] loss: 5.788
# [Epoch number : 12, Mini-batches:  3000] loss: 5.696
# [Epoch number : 12, Mini-batches:  4000] loss: 5.838
# [Epoch number : 12, Mini-batches:  5000] loss: 5.833
# [Epoch number : 12, Mini-batches:  6000] loss: 5.849
#
# output predicted is : tensor([[ -4.3227,  -6.2973,  -2.0967,  ...,  -2.0202,  -3.5087,  -4.7685],
#         [  1.2917,   0.6691,  -3.5713,  ...,  -5.4373,   3.6249,  -3.0551],
#         [  0.4428,  -0.0226,  -1.0579,  ...,  -2.1165,   1.2356,  -0.8738],
#         ...,
#         [ -4.4763, -10.0507,  -1.6778,  ...,  -1.3897,  -6.6004,  -7.7965],
#         [  0.4648,   0.4387,  -0.6439,  ...,  -1.2627,  -0.9244,  -0.1348],
#         [ -5.5427,  -9.7860,  -0.1701,  ...,   2.7893,  -8.5406, -11.8651]])
# LeNet accuracy on 10000 images from test dataset: 59 %
#
# [Epoch number : 13, Mini-batches:  1000] loss: 5.679
# [Epoch number : 13, Mini-batches:  2000] loss: 5.864
# [Epoch number : 13, Mini-batches:  3000] loss: 5.819
# [Epoch number : 13, Mini-batches:  4000] loss: 5.677
# [Epoch number : 13, Mini-batches:  5000] loss: 5.844
# [Epoch number : 13, Mini-batches:  6000] loss: 5.654
#
# output predicted is : tensor([[ -5.5743,  -8.0207,  -3.0083,  ...,  -4.6845,  -2.9974,  -6.1778],
#         [  1.2789,   1.8234,  -6.5521,  ...,  -7.7777,   4.0054,  -2.8602],
#         [ -1.1276,   0.5396,  -3.2671,  ...,  -3.3377,   0.3803,   1.4352],
#         ...,
#         [ -6.5741, -10.7421,  -3.4541,  ...,  -2.9823,  -7.6749,  -9.7853],
#         [ -0.0608,   0.5018,  -0.8260,  ...,  -1.5215,  -2.1439,  -2.8648],
#         [ -5.1305, -10.1327,   0.3578,  ...,   3.9486, -11.6563, -10.3116]])
# LeNet accuracy on 10000 images from test dataset: 62 %
#
# [Epoch number : 14, Mini-batches:  1000] loss: 5.664
# [Epoch number : 14, Mini-batches:  2000] loss: 5.680
# [Epoch number : 14, Mini-batches:  3000] loss: 5.791
# [Epoch number : 14, Mini-batches:  4000] loss: 5.729
# [Epoch number : 14, Mini-batches:  5000] loss: 5.725
# [Epoch number : 14, Mini-batches:  6000] loss: 5.752
#
# output predicted is : tensor([[ -5.4437,  -6.4637,  -2.7989,  ...,  -3.9917,  -2.7880,  -4.6088],
#         [  0.4301,   3.0988,  -7.2884,  ..., -10.5628,   4.5459,  -3.7316],
#         [ -0.2262,   0.1414,  -3.8300,  ...,  -4.4334,   1.6237,   0.8332],
#         ...,
#         [ -6.9063, -10.6132,  -3.0825,  ...,  -1.7314,  -8.0355,  -7.7341],
#         [ -1.4967,   1.8279,  -1.8301,  ...,  -1.6171,  -3.6372,  -0.2453],
#         [ -4.7139,  -6.7109,  -1.6775,  ...,   3.3128,  -5.8829,  -5.8974]])
# LeNet accuracy on 10000 images from test dataset: 62 %
#
# [Epoch number : 15, Mini-batches:  1000] loss: 5.587
# [Epoch number : 15, Mini-batches:  2000] loss: 5.664
# [Epoch number : 15, Mini-batches:  3000] loss: 5.625
# [Epoch number : 15, Mini-batches:  4000] loss: 5.618
# [Epoch number : 15, Mini-batches:  5000] loss: 5.677
# [Epoch number : 15, Mini-batches:  6000] loss: 5.669
#
# output predicted is : tensor([[-2.5953, -4.6098, -1.5751,  ..., -3.3281, -2.1480, -4.1110],
#         [-0.2247,  2.8731, -7.2281,  ..., -9.4052,  4.1542, -2.2867],
#         [-0.5580, -0.1632, -3.6356,  ..., -3.9674,  1.6886,  0.4953],
#         ...,
#         [-5.7318, -9.8560, -2.6078,  ..., -3.7435, -9.0363, -6.6861],
#         [-0.4739,  1.1121, -1.9615,  ..., -2.5350, -5.1879, -2.0513],
#         [-3.4901, -9.7156, -0.5032,  ...,  3.4416, -6.7963, -6.4892]])
# LeNet accuracy on 10000 images from test dataset: 62 %
#
# [Epoch number : 16, Mini-batches:  1000] loss: 5.686
# [Epoch number : 16, Mini-batches:  2000] loss: 5.608
# [Epoch number : 16, Mini-batches:  3000] loss: 5.567
# [Epoch number : 16, Mini-batches:  4000] loss: 5.680
# [Epoch number : 16, Mini-batches:  5000] loss: 5.677
# [Epoch number : 16, Mini-batches:  6000] loss: 5.558
#
# output predicted is : tensor([[ -4.3256,  -5.7070,  -2.3363,  ...,  -2.4426,  -3.1168,  -4.8626],
#         [  0.8521,   1.4228,  -6.6779,  ...,  -9.4868,   3.0059,  -3.1622],
#         [  0.1618,   0.4894,  -2.3858,  ...,  -3.2968,   0.9931,   0.7801],
#         ...,
#         [ -6.2748,  -8.8753,  -2.4535,  ...,  -1.1531,  -7.7731,  -6.1768],
#         [ -2.7020,   1.4590,  -0.9289,  ...,  -2.1875,  -3.7669,  -1.3575],
#         [ -6.0870,  -9.8564,  -0.8342,  ...,   2.6933,  -8.8069, -11.8598]])
# LeNet accuracy on 10000 images from test dataset: 64 %
#
# [Epoch number : 17, Mini-batches:  1000] loss: 5.526
# [Epoch number : 17, Mini-batches:  2000] loss: 5.560
# [Epoch number : 17, Mini-batches:  3000] loss: 5.548
# [Epoch number : 17, Mini-batches:  4000] loss: 5.658
# [Epoch number : 17, Mini-batches:  5000] loss: 5.591
# [Epoch number : 17, Mini-batches:  6000] loss: 5.523
#
# output predicted is : tensor([[-3.8778, -5.4322, -2.1443,  ..., -3.4214, -3.4921, -6.0400],
#         [-0.3056,  1.9209, -4.3299,  ..., -8.9096,  1.8647, -4.1647],
#         [ 0.1292,  0.5550, -1.9957,  ..., -2.5547,  0.7471,  0.7273],
#         ...,
#         [-5.2048, -8.9143, -1.2029,  ..., -1.3525, -7.4411, -5.6333],
#         [-0.2816,  1.8469, -2.5515,  ..., -1.9420, -2.4979, -2.0476],
#         [-3.3069, -6.2119,  0.6749,  ...,  1.3537, -6.4828, -7.6249]])
# LeNet accuracy on 10000 images from test dataset: 61 %
#
# [Epoch number : 18, Mini-batches:  1000] loss: 5.573
# [Epoch number : 18, Mini-batches:  2000] loss: 5.579
# [Epoch number : 18, Mini-batches:  3000] loss: 5.618
# [Epoch number : 18, Mini-batches:  4000] loss: 5.439
# [Epoch number : 18, Mini-batches:  5000] loss: 5.470
# [Epoch number : 18, Mini-batches:  6000] loss: 5.509
#
# output predicted is : tensor([[ -5.9092,  -6.9508,  -3.3116,  ...,  -4.3394,  -4.4020,  -5.9620],
#         [  1.1184,   2.5091,  -8.8240,  ...,  -9.7383,   2.4518,  -0.7647],
#         [ -2.7755,  -0.3124,  -4.5403,  ...,  -4.8260,  -0.4167,  -0.3065],
#         ...,
#         [ -7.1319,  -7.9634,  -2.0280,  ...,  -0.6476,  -9.4910,  -5.7378],
#         [ -2.1436,  -0.7463,  -2.9109,  ...,  -1.6985,  -5.3803,  -4.1032],
#         [ -6.4489, -10.0184,  -1.4152,  ...,   4.0648, -10.3928, -10.5537]])
# LeNet accuracy on 10000 images from test dataset: 63 %
#
# [Epoch number : 19, Mini-batches:  1000] loss: 5.530
# [Epoch number : 19, Mini-batches:  2000] loss: 5.463
# [Epoch number : 19, Mini-batches:  3000] loss: 5.524
# [Epoch number : 19, Mini-batches:  4000] loss: 5.616
# [Epoch number : 19, Mini-batches:  5000] loss: 5.452
# [Epoch number : 19, Mini-batches:  6000] loss: 5.553
#
# output predicted is : tensor([[ -4.2375,  -5.5198,  -2.6110,  ...,  -3.2939,  -3.5713,  -5.1119],
#         [ -0.7451,   1.3877,  -5.6234,  ..., -10.6231,   1.6399,  -3.1145],
#         [ -0.0634,   0.4353,  -1.2298,  ...,  -2.3727,   0.1090,   0.0404],
#         ...,
#         [ -5.4737,  -7.1743,  -2.5586,  ...,  -0.6442,  -7.1566,  -4.6507],
#         [ -1.2946,   0.0499,  -1.8043,  ...,  -2.4286,  -4.2383,  -2.0386],
#         [-10.6786, -13.1976,  -4.0660,  ...,   3.0111, -16.2500, -13.5613]])
# LeNet accuracy on 10000 images from test dataset: 65 %
#
# [Epoch number : 20, Mini-batches:  1000] loss: 5.424
# [Epoch number : 20, Mini-batches:  2000] loss: 5.497
# [Epoch number : 20, Mini-batches:  3000] loss: 5.487
# [Epoch number : 20, Mini-batches:  4000] loss: 5.515
# [Epoch number : 20, Mini-batches:  5000] loss: 5.507
# [Epoch number : 20, Mini-batches:  6000] loss: 5.483
#
# output predicted is : tensor([[-3.0476, -2.6635, -1.7306,  ..., -1.4333, -3.3476, -1.3708],
#         [-0.5483,  0.9231, -4.7916,  ..., -8.5355,  1.8571, -1.8408],
#         [-0.1970,  0.4004, -1.6105,  ..., -1.9279, -0.4723,  0.7288],
#         ...,
#         [-5.5189, -9.2204, -2.8688,  ..., -2.4128, -8.9007, -6.9447],
#         [-1.5127,  1.0992, -2.2443,  ..., -1.6725, -4.5450, -0.6232],
#         [-3.8713, -6.6382, -1.3453,  ...,  2.8862, -8.8816, -6.7498]])
# LeNet accuracy on 10000 images from test dataset: 61 %
#
# [Epoch number : 21, Mini-batches:  1000] loss: 5.527
# [Epoch number : 21, Mini-batches:  2000] loss: 5.385
# [Epoch number : 21, Mini-batches:  3000] loss: 5.513
# [Epoch number : 21, Mini-batches:  4000] loss: 5.384
# [Epoch number : 21, Mini-batches:  5000] loss: 5.514
# [Epoch number : 21, Mini-batches:  6000] loss: 5.455
#
# output predicted is : tensor([[ -5.1207,  -4.8420,  -3.2416,  ...,  -3.3430,  -4.2828,  -4.6543],
#         [ -0.5565,   1.8275,  -6.3546,  ...,  -9.3767,   2.0584,  -3.7352],
#         [  0.0721,   0.1493,  -2.0008,  ...,  -2.8817,   0.4455,  -0.2743],
#         ...,
#         [ -6.8866,  -9.3145,  -2.6560,  ...,  -2.6271,  -7.4457,  -7.0977],
#         [ -1.7662,  -1.6686,  -2.4389,  ...,  -1.4767,  -4.0161,  -4.2206],
#         [ -5.5572, -10.2948,  -0.7110,  ...,   0.5339,  -8.6292,  -9.8985]])
# LeNet accuracy on 10000 images from test dataset: 63 %
#
# [Epoch number : 22, Mini-batches:  1000] loss: 5.398
# [Epoch number : 22, Mini-batches:  2000] loss: 5.535
# [Epoch number : 22, Mini-batches:  3000] loss: 5.463
# [Epoch number : 22, Mini-batches:  4000] loss: 5.466
# [Epoch number : 22, Mini-batches:  5000] loss: 5.414
# [Epoch number : 22, Mini-batches:  6000] loss: 5.545
#
# output predicted is : tensor([[ -3.9153,  -4.5460,  -3.3155,  ...,  -3.9887,  -2.2170,  -4.9278],
#         [ -0.1700,  -0.2356,  -7.5190,  ..., -11.1687,   3.0377,  -5.1356],
#         [ -1.0726,  -2.9280,  -3.5669,  ...,  -4.7391,  -0.4796,  -1.0338],
#         ...,
#         [ -5.6653,  -7.8669,  -2.3538,  ...,  -3.9783,  -6.5378,  -7.3067],
#         [ -0.9329,  -0.4628,  -1.8209,  ...,  -2.1313,  -4.2151,  -3.8882],
#         [ -1.6035,  -7.0720,  -0.0900,  ...,   0.0228,  -7.0685,  -8.6894]])
# LeNet accuracy on 10000 images from test dataset: 63 %
#
# [Epoch number : 23, Mini-batches:  1000] loss: 5.376
# [Epoch number : 23, Mini-batches:  2000] loss: 5.354
# [Epoch number : 23, Mini-batches:  3000] loss: 5.521
# [Epoch number : 23, Mini-batches:  4000] loss: 5.428
# [Epoch number : 23, Mini-batches:  5000] loss: 5.389
# [Epoch number : 23, Mini-batches:  6000] loss: 5.393
#
# output predicted is : tensor([[-3.2325, -4.1744, -3.6709,  ..., -3.0337, -2.3982, -2.7643],
#         [-0.4338,  1.7991, -6.3082,  ..., -8.7693,  0.6422, -1.9004],
#         [-1.5683, -0.5347, -3.0603,  ..., -3.1737, -0.5463,  0.0794],
#         ...,
#         [-6.0354, -9.4329, -2.2174,  ..., -2.5651, -7.6752, -5.9817],
#         [-1.9049, -0.6212, -3.5576,  ..., -1.9223, -5.5989, -3.4237],
#         [-3.9551, -5.5567, -0.7780,  ...,  1.4869, -7.9506, -6.3379]])
# LeNet accuracy on 10000 images from test dataset: 64 %
#
# [Epoch number : 24, Mini-batches:  1000] loss: 5.408
# [Epoch number : 24, Mini-batches:  2000] loss: 5.394
# [Epoch number : 24, Mini-batches:  3000] loss: 5.319
# [Epoch number : 24, Mini-batches:  4000] loss: 5.546
# [Epoch number : 24, Mini-batches:  5000] loss: 5.414
# [Epoch number : 24, Mini-batches:  6000] loss: 5.371
#
# output predicted is : tensor([[ -5.2648,  -5.0991,  -3.4386,  ...,  -2.9114,  -4.7836,  -4.1457],
#         [ -2.8614,  -4.2913,  -7.5315,  ..., -12.5864,   0.3860,  -8.1699],
#         [ -0.8616,  -0.8893,  -2.2125,  ...,  -3.3615,   0.6883,  -1.2975],
#         ...,
#         [ -6.6453, -13.0017,  -3.1538,  ...,  -4.3406,  -9.4517,  -8.0691],
#         [ -1.9372,  -1.3231,  -3.0557,  ...,  -1.3741,  -5.6668,  -3.3424],
#         [ -5.4491,  -7.8044,   0.2701,  ...,   0.0505,  -8.1568,  -9.2658]])
# LeNet accuracy on 10000 images from test dataset: 65 %
#
# [Epoch number : 25, Mini-batches:  1000] loss: 5.320
# [Epoch number : 25, Mini-batches:  2000] loss: 5.468
# [Epoch number : 25, Mini-batches:  3000] loss: 5.411
# [Epoch number : 25, Mini-batches:  4000] loss: 5.302
# [Epoch number : 25, Mini-batches:  5000] loss: 5.371
# [Epoch number : 25, Mini-batches:  6000] loss: 5.416
#
# output predicted is : tensor([[ -5.3067,  -4.7495,  -4.4475,  ...,  -4.1541,  -3.5764,  -5.1342],
#         [ -1.9598,  -1.4891,  -7.4214,  ..., -12.1043,   1.2577,  -4.9380],
#         [ -0.7904,  -0.2896,  -1.8763,  ...,  -3.5638,   0.4720,  -0.7474],
#         ...,
#         [ -6.3237,  -8.9177,  -2.2440,  ...,  -2.8984,  -8.8512,  -5.4377],
#         [ -3.3622,   0.0405,  -2.6473,  ...,  -4.0930,  -5.6130,  -3.9176],
#         [ -4.5766,  -8.8462,  -0.4511,  ...,   0.8399,  -7.5164,  -7.2371]])
# LeNet accuracy on 10000 images from test dataset: 66 %
#
# [Epoch number : 26, Mini-batches:  1000] loss: 5.344
# [Epoch number : 26, Mini-batches:  2000] loss: 5.383
# [Epoch number : 26, Mini-batches:  3000] loss: 5.291
# [Epoch number : 26, Mini-batches:  4000] loss: 5.287
# [Epoch number : 26, Mini-batches:  5000] loss: 5.305
# [Epoch number : 26, Mini-batches:  6000] loss: 5.546
#
# output predicted is : tensor([[-3.0383, -3.0023, -3.9016,  ..., -4.8878, -1.5322, -3.8108],
#         [-0.4040,  0.6676, -6.3426,  ..., -9.5601, -0.1289, -3.9867],
#         [-1.4333, -1.2399, -3.2735,  ..., -4.1005, -0.4845, -0.4020],
#         ...,
#         [-7.2924, -7.7914, -3.9296,  ..., -3.0257, -8.8247, -6.1963],
#         [-2.9174,  0.4363, -4.7190,  ..., -4.3412, -5.7063, -2.8995],
#         [-3.4807, -6.6904, -1.0116,  ...,  1.6736, -6.3981, -5.8375]])
# LeNet accuracy on 10000 images from test dataset: 63 %
#
# [Epoch number : 27, Mini-batches:  1000] loss: 5.400
# [Epoch number : 27, Mini-batches:  2000] loss: 5.391
# [Epoch number : 27, Mini-batches:  3000] loss: 5.245
# [Epoch number : 27, Mini-batches:  4000] loss: 5.417
# [Epoch number : 27, Mini-batches:  5000] loss: 5.299
# [Epoch number : 27, Mini-batches:  6000] loss: 5.296
#
# output predicted is : tensor([[ -4.5070,  -4.4407,  -4.0554,  ...,  -3.1428,  -3.5360,  -2.7037],
#         [ -0.6305,   2.5988,  -6.3934,  ...,  -9.6621,  -0.1180,  -2.3027],
#         [ -0.8097,  -0.7802,  -2.4890,  ...,  -3.0984,  -0.3221,  -0.2987],
#         ...,
#         [ -9.1013,  -9.3565,  -3.6793,  ...,  -2.0733, -11.1400,  -6.6276],
#         [ -3.3735,   0.3617,  -5.2887,  ...,  -3.7396,  -6.3463,  -4.6073],
#         [ -5.5635,  -8.9829,  -2.3528,  ...,   1.7235,  -9.0787,  -6.9920]])
# LeNet accuracy on 10000 images from test dataset: 65 %
#
# [Epoch number : 28, Mini-batches:  1000] loss: 5.305
# [Epoch number : 28, Mini-batches:  2000] loss: 5.238
# [Epoch number : 28, Mini-batches:  3000] loss: 5.382
# [Epoch number : 28, Mini-batches:  4000] loss: 5.445
# [Epoch number : 28, Mini-batches:  5000] loss: 5.367
# [Epoch number : 28, Mini-batches:  6000] loss: 5.313
#
# output predicted is : tensor([[ -3.2050,  -3.5904,  -2.4443,  ...,  -2.7792,  -2.3090,  -2.9436],
#         [ -0.5573,   1.6815,  -6.2833,  ...,  -8.6348,  -1.3713,  -2.0177],
#         [ -0.8743,  -0.2230,  -1.8549,  ...,  -2.5935,  -0.5573,  -0.1768],
#         ...,
#         [ -9.4114, -13.1961,  -2.7597,  ...,  -3.0528, -14.1623,  -8.5549],
#         [ -2.7081,  -0.8546,  -3.8806,  ...,  -3.6039,  -7.8359,  -5.8485],
#         [ -5.9418,  -9.9830,  -1.3315,  ...,   2.4455, -11.7762,  -7.1777]])
# LeNet accuracy on 10000 images from test dataset: 64 %
#
# [Epoch number : 29, Mini-batches:  1000] loss: 5.332
# [Epoch number : 29, Mini-batches:  2000] loss: 5.255
# [Epoch number : 29, Mini-batches:  3000] loss: 5.346
# [Epoch number : 29, Mini-batches:  4000] loss: 5.252
# [Epoch number : 29, Mini-batches:  5000] loss: 5.387
# [Epoch number : 29, Mini-batches:  6000] loss: 5.271
#
# output predicted is : tensor([[ -6.3839,  -5.4150,  -3.8611,  ...,  -3.4874,  -4.5923,  -5.0881],
#         [ -4.5944,  -0.9297,  -9.9217,  ..., -11.8131,   0.1039,  -3.7371],
#         [ -3.5727,  -3.3802,  -4.9942,  ...,  -5.4663,  -2.5404,  -1.7197],
#         ...,
#         [-10.5045, -13.8739,  -4.7855,  ...,  -2.9640, -12.6686, -10.2645],
#         [ -3.0331,  -0.9543,  -5.0960,  ...,  -4.5196,  -8.0058,  -6.4515],
#         [ -3.9425,  -8.7150,  -2.1095,  ...,   2.5464,  -8.1686,  -6.8145]])
# LeNet accuracy on 10000 images from test dataset: 65 %
#
# [Epoch number : 30, Mini-batches:  1000] loss: 5.305
# [Epoch number : 30, Mini-batches:  2000] loss: 5.314
# [Epoch number : 30, Mini-batches:  3000] loss: 5.361
# [Epoch number : 30, Mini-batches:  4000] loss: 5.255
# [Epoch number : 30, Mini-batches:  5000] loss: 5.230
# [Epoch number : 30, Mini-batches:  6000] loss: 5.294
#
# output predicted is : tensor([[-5.0475e+00, -7.1928e+00, -4.6728e+00,  ..., -5.9757e+00,
#          -2.7786e+00, -6.9057e+00],
#         [-4.4935e+00, -3.0340e+00, -1.1127e+01,  ..., -1.6627e+01,
#          -5.0286e-01, -6.5118e+00],
#         [ 1.3393e-02, -1.2688e+00, -1.7555e+00,  ..., -3.3509e+00,
#           1.0578e+00, -1.1520e+00],
#         ...,
#         [-9.4578e+00, -1.0653e+01, -3.6104e+00,  ..., -3.5530e+00,
#          -1.1235e+01, -1.0519e+01],
#         [-3.0421e+00,  7.8434e-02, -4.2183e+00,  ..., -5.4080e+00,
#          -6.2617e+00, -4.9052e+00],
#         [-6.9848e+00, -8.3698e+00, -2.0020e+00,  ...,  2.0310e+00,
#          -1.0921e+01, -7.5275e+00]])
# LeNet accuracy on 10000 images from test dataset: 65 %
#
# [Epoch number : 31, Mini-batches:  1000] loss: 5.251
# [Epoch number : 31, Mini-batches:  2000] loss: 5.216
# [Epoch number : 31, Mini-batches:  3000] loss: 5.342
# [Epoch number : 31, Mini-batches:  4000] loss: 5.334
# [Epoch number : 31, Mini-batches:  5000] loss: 5.187
# [Epoch number : 31, Mini-batches:  6000] loss: 5.283
#
# output predicted is : tensor([[-6.6215e+00, -5.2691e+00, -4.9239e+00,  ..., -5.1170e+00,
#          -5.1236e+00, -4.7381e+00],
#         [-3.1866e+00, -2.0357e-01, -9.7376e+00,  ..., -1.5311e+01,
#          -1.1481e+00, -6.4025e+00],
#         [-6.8314e-01, -7.0376e-03, -2.6121e+00,  ..., -4.7338e+00,
#           3.8197e-01, -1.4509e+00],
#         ...,
#         [-9.6559e+00, -1.0380e+01, -5.5811e+00,  ..., -4.1096e+00,
#          -9.6657e+00, -6.4835e+00],
#         [-4.2547e+00, -1.1526e+00, -5.0600e+00,  ..., -8.2209e+00,
#          -7.4398e+00, -7.8126e+00],
#         [-5.3675e+00, -1.0703e+01, -2.6649e+00,  ...,  1.0759e+00,
#          -9.5816e+00, -7.0973e+00]])
# LeNet accuracy on 10000 images from test dataset: 65 %
#
# [Epoch number : 32, Mini-batches:  1000] loss: 5.312
# [Epoch number : 32, Mini-batches:  2000] loss: 5.250
# [Epoch number : 32, Mini-batches:  3000] loss: 5.376
# [Epoch number : 32, Mini-batches:  4000] loss: 5.231
# [Epoch number : 32, Mini-batches:  5000] loss: 5.295
# [Epoch number : 32, Mini-batches:  6000] loss: 5.214
#
# output predicted is : tensor([[ -5.0583,  -5.2576,  -3.6765,  ...,  -4.4772,  -3.8304,  -4.1094],
#         [ -4.2347,  -0.3129, -11.1318,  ..., -13.4000,  -2.4801,  -4.8462],
#         [ -0.9431,  -1.5618,  -1.8400,  ...,  -2.7007,   0.1342,  -0.5515],
#         ...,
#         [ -9.4567, -15.0819,  -3.9037,  ...,  -3.8417, -12.0535,  -8.7724],
#         [ -4.0747,  -1.8605,  -4.0095,  ...,  -5.2030,  -8.4311,  -6.4842],
#         [ -8.7619, -11.4640,  -3.4465,  ...,   1.9107, -12.2070, -10.3457]])
# LeNet accuracy on 10000 images from test dataset: 66 %
#
# [Epoch number : 33, Mini-batches:  1000] loss: 5.138
# [Epoch number : 33, Mini-batches:  2000] loss: 5.294
# [Epoch number : 33, Mini-batches:  3000] loss: 5.375
# [Epoch number : 33, Mini-batches:  4000] loss: 5.345
# [Epoch number : 33, Mini-batches:  5000] loss: 5.189
# [Epoch number : 33, Mini-batches:  6000] loss: 5.254
#
# output predicted is : tensor([[ -5.1338,  -4.7204,  -4.4716,  ...,  -5.8983,  -4.5943,  -5.4762],
#         [ -3.3695,   1.3280,  -8.4311,  ..., -11.0704,  -3.0856,  -3.9278],
#         [ -0.9788,  -0.2652,  -1.9668,  ...,  -2.7062,  -0.0295,  -0.4072],
#         ...,
#         [ -7.7616,  -9.2411,  -4.1343,  ...,  -3.4829,  -9.6951,  -7.8965],
#         [ -3.2278,  -1.0152,  -4.9675,  ...,  -4.9695,  -6.8209,  -5.4437],
#         [ -5.7308,  -7.0797,  -2.2976,  ...,   0.1890,  -9.2072,  -7.7351]])
# LeNet accuracy on 10000 images from test dataset: 65 %
#
# [Epoch number : 34, Mini-batches:  1000] loss: 5.084
# [Epoch number : 34, Mini-batches:  2000] loss: 5.295
# [Epoch number : 34, Mini-batches:  3000] loss: 5.301
# [Epoch number : 34, Mini-batches:  4000] loss: 5.291
# [Epoch number : 34, Mini-batches:  5000] loss: 5.223
# [Epoch number : 34, Mini-batches:  6000] loss: 5.248
#
# output predicted is : tensor([[ -5.0679,  -4.9640,  -4.1049,  ...,  -3.4984,  -4.3113,  -3.3189],
#         [ -1.8176,   0.4140,  -7.0049,  ...,  -8.9400,  -0.4313,  -3.3466],
#         [ -2.0225,  -1.7192,  -3.4653,  ...,  -3.7295,  -0.5871,  -0.7609],
#         ...,
#         [ -8.1296, -11.5845,  -2.7950,  ...,  -3.9526,  -9.6764,  -7.2232],
#         [ -4.1576,   0.6880,  -4.9584,  ...,  -4.2513,  -4.8459,  -2.9623],
#         [ -6.0636, -11.4750,  -5.2614,  ...,   2.2211, -10.5449,  -8.5402]])
# LeNet accuracy on 10000 images from test dataset: 64 %
#
# [Epoch number : 35, Mini-batches:  1000] loss: 5.221
# [Epoch number : 35, Mini-batches:  2000] loss: 5.274
# [Epoch number : 35, Mini-batches:  3000] loss: 5.200
# [Epoch number : 35, Mini-batches:  4000] loss: 5.342
# [Epoch number : 35, Mini-batches:  5000] loss: 5.253
# [Epoch number : 35, Mini-batches:  6000] loss: 5.154
#
# output predicted is : tensor([[ -6.7686,  -6.0332,  -4.2855,  ...,  -4.6243,  -5.2381,  -5.3001],
#         [ -4.4575,  -0.0644, -10.8131,  ..., -15.9336,  -2.4266,  -5.9177],
#         [ -1.2188,  -1.3708,  -2.3230,  ...,  -3.0511,   0.1976,  -0.8015],
#         ...,
#         [ -9.8640, -13.9882,  -5.7204,  ...,  -4.9597, -10.6173,  -9.4192],
#         [ -3.1036,  -1.2057,  -3.9796,  ...,  -5.0385,  -5.9324,  -4.6146],
#         [ -4.6992, -10.9305,  -3.0642,  ...,   1.2810, -11.4046,  -8.9794]])
# LeNet accuracy on 10000 images from test dataset: 66 %
#
# [Epoch number : 36, Mini-batches:  1000] loss: 5.216
# [Epoch number : 36, Mini-batches:  2000] loss: 5.297
# [Epoch number : 36, Mini-batches:  3000] loss: 5.154
# [Epoch number : 36, Mini-batches:  4000] loss: 5.227
# [Epoch number : 36, Mini-batches:  5000] loss: 5.266
# [Epoch number : 36, Mini-batches:  6000] loss: 5.248
#
# output predicted is : tensor([[ -7.0375,  -7.4283,  -5.5694,  ...,  -4.6710,  -7.5294,  -6.3606],
#         [ -5.2422,  -1.9141,  -8.8308,  ..., -11.7576,  -1.0191,  -5.5509],
#         [ -2.3186,  -2.6293,  -3.5355,  ...,  -2.9188,  -0.9494,  -0.9995],
#         ...,
#         [-11.3107, -12.1800,  -6.4599,  ...,  -6.0322, -14.0222,  -9.3607],
#         [ -4.6469,  -0.2450,  -4.8153,  ...,  -5.9870,  -5.2969,  -3.6798],
#         [ -6.2287, -10.5221,  -2.6385,  ...,   0.3822, -10.7187,  -9.0451]])
# LeNet accuracy on 10000 images from test dataset: 64 %
#
# [Epoch number : 37, Mini-batches:  1000] loss: 5.195
# [Epoch number : 37, Mini-batches:  2000] loss: 5.216
# [Epoch number : 37, Mini-batches:  3000] loss: 5.251
# [Epoch number : 37, Mini-batches:  4000] loss: 5.255
# [Epoch number : 37, Mini-batches:  5000] loss: 5.364
# [Epoch number : 37, Mini-batches:  6000] loss: 5.235
#
# output predicted is : tensor([[ -8.1532,  -7.7569,  -6.6791,  ...,  -6.9716,  -6.3434,  -6.9639],
#         [ -6.3828,  -3.6390, -12.8267,  ..., -17.9971,  -2.8619, -10.2262],
#         [ -1.7296,  -1.8963,  -3.3236,  ...,  -4.0156,   0.3289,  -1.6789],
#         ...,
#         [ -8.5859,  -9.4143,  -4.1208,  ...,  -4.9049, -10.0781,  -7.5429],
#         [ -5.9741,  -0.9502,  -8.5573,  ...,  -9.9428,  -7.3856,  -6.5398],
#         [ -5.3367,  -6.2389,  -2.9673,  ...,   0.1944,  -6.9159,  -5.5373]])
# LeNet accuracy on 10000 images from test dataset: 66 %
#
# [Epoch number : 38, Mini-batches:  1000] loss: 5.131
# [Epoch number : 38, Mini-batches:  2000] loss: 5.217
# [Epoch number : 38, Mini-batches:  3000] loss: 5.259
# [Epoch number : 38, Mini-batches:  4000] loss: 5.235
# [Epoch number : 38, Mini-batches:  5000] loss: 5.184
# [Epoch number : 38, Mini-batches:  6000] loss: 5.238
#
# output predicted is : tensor([[ -5.7859,  -5.2972,  -4.7222,  ...,  -4.5614,  -5.1574,  -4.5510],
#         [ -3.6779,  -2.5340,  -8.3097,  ..., -11.9758,  -1.9723,  -7.6514],
#         [ -0.8667,  -2.0284,  -1.5013,  ...,  -3.1156,  -0.0892,  -1.9021],
#         ...,
#         [-10.6040,  -9.6055,  -5.9934,  ...,  -4.6942, -12.1327,  -7.8214],
#         [ -3.5834,  -2.4632,  -4.2500,  ...,  -4.3507,  -6.9073,  -5.0670],
#         [ -6.2483,  -8.4583,  -4.1321,  ...,   1.0992, -11.0783,  -7.4270]])
# LeNet accuracy on 10000 images from test dataset: 66 %
#
# [Epoch number : 39, Mini-batches:  1000] loss: 5.199
# [Epoch number : 39, Mini-batches:  2000] loss: 5.186
# [Epoch number : 39, Mini-batches:  3000] loss: 5.255
# [Epoch number : 39, Mini-batches:  4000] loss: 5.135
# [Epoch number : 39, Mini-batches:  5000] loss: 5.241
# [Epoch number : 39, Mini-batches:  6000] loss: 5.183
#
# output predicted is : tensor([[ -7.0392,  -7.5137,  -5.9255,  ...,  -5.4656,  -6.6815,  -6.4215],
#         [ -5.0781,  -0.6410, -10.0666,  ..., -12.1198,  -2.1303,  -5.5790],
#         [ -1.7439,  -2.0861,  -2.5515,  ...,  -3.0724,  -0.0241,  -1.1561],
#         ...,
#         [ -8.6060, -12.9143,  -5.7455,  ...,  -5.2889, -10.2749,  -9.5870],
#         [ -3.2837,   0.3285,  -4.0323,  ...,  -4.7107,  -3.6677,  -2.4132],
#         [ -6.1419, -10.1152,  -3.7700,  ...,   0.8925, -10.7097,  -7.2313]])
# LeNet accuracy on 10000 images from test dataset: 66 %
#
# [Epoch number : 40, Mini-batches:  1000] loss: 5.148
# [Epoch number : 40, Mini-batches:  2000] loss: 5.216
# [Epoch number : 40, Mini-batches:  3000] loss: 5.155
# [Epoch number : 40, Mini-batches:  4000] loss: 5.222
# [Epoch number : 40, Mini-batches:  5000] loss: 5.129
# [Epoch number : 40, Mini-batches:  6000] loss: 5.260
#
# output predicted is : tensor([[-10.9190,  -9.5941,  -7.5892,  ...,  -8.9372,  -8.7072,  -8.3646],
#         [ -6.1377,  -6.5435, -11.1569,  ..., -15.7294,  -1.6498, -10.2727],
#         [ -2.1198,  -2.2406,  -3.7647,  ...,  -4.1426,  -0.1031,  -2.0252],
#         ...,
#         [-12.0649, -13.1147,  -8.5646,  ...,  -8.5844, -13.8908, -10.9903],
#         [ -5.8033,  -3.2672,  -7.1777,  ...,  -6.5181,  -8.1756,  -6.4782],
#         [ -6.4747,  -9.9034,  -4.7394,  ...,   0.8852, -10.3787,  -8.6135]])
# LeNet accuracy on 10000 images from test dataset: 66 %
#
# [Epoch number : 41, Mini-batches:  1000] loss: 5.188
# [Epoch number : 41, Mini-batches:  2000] loss: 5.042
# [Epoch number : 41, Mini-batches:  3000] loss: 5.093
# [Epoch number : 41, Mini-batches:  4000] loss: 5.215
# [Epoch number : 41, Mini-batches:  5000] loss: 5.229
# [Epoch number : 41, Mini-batches:  6000] loss: 5.169
#
# output predicted is : tensor([[-11.4152,  -9.0756,  -8.8144,  ...,  -8.3914,  -7.3020,  -8.4327],
#         [ -5.9300,  -4.4007, -11.0572,  ..., -13.6460,  -1.4143,  -8.7081],
#         [ -2.6836,  -1.3638,  -4.1654,  ...,  -3.8026,  -0.2525,  -0.6006],
#         ...,
#         [-13.8901, -13.4748,  -9.1476,  ...,  -9.1296, -13.6442, -12.2897],
#         [ -6.5040,  -1.8670,  -6.3540,  ...,  -5.1210,  -8.4288,  -5.1263],
#         [-10.2018,  -9.7566,  -4.7000,  ...,  -0.6985, -13.6962,  -7.9281]])
# LeNet accuracy on 10000 images from test dataset: 67 %
#
# [Epoch number : 42, Mini-batches:  1000] loss: 5.212
# [Epoch number : 42, Mini-batches:  2000] loss: 5.116
# [Epoch number : 42, Mini-batches:  3000] loss: 5.147
# [Epoch number : 42, Mini-batches:  4000] loss: 5.143
# [Epoch number : 42, Mini-batches:  5000] loss: 5.234
# [Epoch number : 42, Mini-batches:  6000] loss: 5.129
#
# output predicted is : tensor([[ -8.2847,  -8.1687,  -7.8662,  ...,  -7.6576,  -6.1692,  -6.6337],
#         [ -5.2947,  -2.0266, -11.0578,  ..., -12.8235,  -2.3109,  -5.4250],
#         [ -2.5095,  -0.8639,  -5.0045,  ...,  -5.4237,  -1.1137,  -1.1033],
#         ...,
#         [-11.6141, -14.5332,  -8.6812,  ...,  -6.9754, -13.8691, -12.7201],
#         [ -5.5141,  -2.4829,  -5.9441,  ...,  -5.0763,  -7.0161,  -5.0320],
#         [ -6.1778,  -8.4311,  -3.7354,  ...,  -0.2471,  -8.5850,  -7.5054]])
# LeNet accuracy on 10000 images from test dataset: 65 %
#
# [Epoch number : 43, Mini-batches:  1000] loss: 5.140
# [Epoch number : 43, Mini-batches:  2000] loss: 5.168
# [Epoch number : 43, Mini-batches:  3000] loss: 5.187
# [Epoch number : 43, Mini-batches:  4000] loss: 5.241
# [Epoch number : 43, Mini-batches:  5000] loss: 5.129
# [Epoch number : 43, Mini-batches:  6000] loss: 5.268
#
# output predicted is : tensor([[ -4.0335,  -4.5427,  -4.0997,  ...,  -3.9754,  -3.3188,  -2.7546],
#         [ -5.5035,  -3.1558, -10.1634,  ..., -14.8065,  -2.9657, -10.1600],
#         [ -1.4794,  -1.1135,  -3.6236,  ...,  -5.2120,  -1.0042,  -2.0337],
#         ...,
#         [-12.1865, -12.9810,  -9.4409,  ...,  -7.5832, -12.2292,  -9.1457],
#         [ -3.9012,  -0.7983,  -4.9172,  ...,  -5.1374,  -5.2968,  -4.2051],
#         [ -6.8241,  -9.9469,  -4.7498,  ...,  -0.5721, -11.0421,  -7.0905]])
# LeNet accuracy on 10000 images from test dataset: 66 %
#
# [Epoch number : 44, Mini-batches:  1000] loss: 5.132
# [Epoch number : 44, Mini-batches:  2000] loss: 5.035
# [Epoch number : 44, Mini-batches:  3000] loss: 5.199
# [Epoch number : 44, Mini-batches:  4000] loss: 5.239
# [Epoch number : 44, Mini-batches:  5000] loss: 5.127
# [Epoch number : 44, Mini-batches:  6000] loss: 5.090
#
# output predicted is : tensor([[ -8.9044,  -8.7078,  -7.1642,  ...,  -7.0939,  -8.1958,  -7.4087],
#         [ -4.8535,  -3.1711,  -9.6128,  ..., -12.1137,  -1.7078,  -7.7994],
#         [ -1.9757,  -1.5495,  -4.0535,  ...,  -4.7629,  -0.5169,  -1.9401],
#         ...,
#         [-12.7315, -15.1560,  -9.5209,  ...,  -8.0926, -12.7567, -12.2265],
#         [ -3.0316,  -0.7044,  -5.0184,  ...,  -7.6584,  -4.3800,  -4.7659],
#         [ -6.4927, -10.9953,  -4.2211,  ...,  -0.3578, -11.7664,  -9.9849]])
# LeNet accuracy on 10000 images from test dataset: 67 %
#
# [Epoch number : 45, Mini-batches:  1000] loss: 5.016
# [Epoch number : 45, Mini-batches:  2000] loss: 5.253
# [Epoch number : 45, Mini-batches:  3000] loss: 5.012
# [Epoch number : 45, Mini-batches:  4000] loss: 5.119
# [Epoch number : 45, Mini-batches:  5000] loss: 5.214
# [Epoch number : 45, Mini-batches:  6000] loss: 5.098
#
# output predicted is : tensor([[ -9.4102,  -8.9069,  -8.4650,  ...,  -8.7378,  -7.5528,  -8.4537],
#         [ -4.5689,  -3.0199,  -9.1708,  ..., -12.3342,  -1.8701,  -7.6604],
#         [ -1.9899,  -1.2992,  -3.2734,  ...,  -3.3831,  -0.8411,  -1.4029],
#         ...,
#         [-14.2659, -15.0030, -10.5120,  ..., -10.3082, -13.2495, -13.1354],
#         [ -3.5945,  -2.1528,  -6.1174,  ...,  -7.4920,  -4.9649,  -5.1099],
#         [ -7.6861,  -9.5171,  -4.6119,  ...,   0.1761, -11.6514,  -9.4545]])
# LeNet accuracy on 10000 images from test dataset: 67 %
#
# [Epoch number : 46, Mini-batches:  1000] loss: 5.105
# [Epoch number : 46, Mini-batches:  2000] loss: 5.187
# [Epoch number : 46, Mini-batches:  3000] loss: 5.311
# [Epoch number : 46, Mini-batches:  4000] loss: 5.089
# [Epoch number : 46, Mini-batches:  5000] loss: 5.157
# [Epoch number : 46, Mini-batches:  6000] loss: 5.253
#
# output predicted is : tensor([[ -6.9449,  -6.5038,  -5.7432,  ...,  -5.7259,  -5.4378,  -5.2572],
#         [ -5.2428,  -5.4626, -11.6626,  ..., -15.4018,  -3.6265,  -8.2773],
#         [ -2.0697,  -2.5570,  -4.8387,  ...,  -6.0168,  -0.9923,  -1.6866],
#         ...,
#         [-16.6651, -15.6069,  -9.9053,  ...,  -9.9657, -13.8184, -14.0374],
#         [ -2.8438,  -0.0922,  -4.6501,  ...,  -6.5725,  -3.7609,  -3.2193],
#         [ -6.4485,  -8.4693,  -4.2093,  ...,  -2.4450, -10.8272,  -7.2380]])
# LeNet accuracy on 10000 images from test dataset: 67 %
#
# [Epoch number : 47, Mini-batches:  1000] loss: 5.033
# [Epoch number : 47, Mini-batches:  2000] loss: 5.207
# [Epoch number : 47, Mini-batches:  3000] loss: 5.113
# [Epoch number : 47, Mini-batches:  4000] loss: 5.175
# [Epoch number : 47, Mini-batches:  5000] loss: 5.128
# [Epoch number : 47, Mini-batches:  6000] loss: 5.053
#
# output predicted is : tensor([[ -7.2171,  -8.0325,  -6.3848,  ...,  -6.2808,  -7.2225,  -7.0926],
#         [ -6.1558,  -4.3582, -11.4833,  ..., -12.9242,  -3.5104,  -9.4184],
#         [ -2.6672,  -2.5166,  -4.3832,  ...,  -3.7877,  -1.2910,  -1.9596],
#         ...,
#         [-17.1288, -17.2775, -11.7078,  ..., -12.3411, -16.1219, -16.2747],
#         [ -3.6481,  -2.1587,  -6.4555,  ...,  -5.9167,  -6.7852,  -6.5255],
#         [ -5.4812, -10.6393,  -4.4627,  ...,  -1.4243, -11.0690,  -9.8361]])
# LeNet accuracy on 10000 images from test dataset: 66 %
#
# [Epoch number : 48, Mini-batches:  1000] loss: 5.129
# [Epoch number : 48, Mini-batches:  2000] loss: 5.046
# [Epoch number : 48, Mini-batches:  3000] loss: 5.056
# [Epoch number : 48, Mini-batches:  4000] loss: 5.170
# [Epoch number : 48, Mini-batches:  5000] loss: 5.056
# [Epoch number : 48, Mini-batches:  6000] loss: 5.256
#
# output predicted is : tensor([[ -4.1632,  -4.4504,  -4.7181,  ...,  -4.7838,  -3.1258,  -3.4503],
#         [ -9.4030,  -5.7023, -13.9653,  ..., -17.5043,  -4.4453, -12.1677],
#         [ -2.7218,  -2.2065,  -4.7728,  ...,  -5.0377,  -1.1881,  -2.0943],
#         ...,
#         [-16.9412, -15.4034, -11.2635,  ..., -10.9231, -16.6927, -13.6439],
#         [ -4.7372,  -0.4903,  -6.3023,  ...,  -6.9349,  -5.7233,  -5.0439],
#         [ -5.8196,  -8.5064,  -4.8022,  ...,  -1.2280, -10.6049,  -8.1294]])
# LeNet accuracy on 10000 images from test dataset: 67 %
#
# [Epoch number : 49, Mini-batches:  1000] loss: 5.110
# [Epoch number : 49, Mini-batches:  2000] loss: 5.197
# [Epoch number : 49, Mini-batches:  3000] loss: 5.123
# [Epoch number : 49, Mini-batches:  4000] loss: 5.186
# [Epoch number : 49, Mini-batches:  5000] loss: 5.125
# [Epoch number : 49, Mini-batches:  6000] loss: 5.100
#
# output predicted is : tensor([[ -6.3850,  -6.2325,  -5.0911,  ...,  -4.7146,  -5.1531,  -4.0700],
#         [ -7.1798,  -4.3325, -12.5038,  ..., -15.2748,  -5.0207,  -9.9099],
#         [ -2.2662,  -2.6179,  -3.7429,  ...,  -4.4835,  -1.0423,  -2.7204],
#         ...,
#         [-18.7003, -17.7583, -11.3932,  ..., -12.2152, -18.2030, -16.9770],
#         [ -3.8820,  -2.5651,  -5.4495,  ...,  -5.7752,  -6.6250,  -5.5993],
#         [ -7.2333, -10.1999,  -5.3429,  ...,   0.9758, -12.7829, -10.2761]])
# LeNet accuracy on 10000 images from test dataset: 67 %
#
# [Epoch number : 50, Mini-batches:  1000] loss: 4.974
# [Epoch number : 50, Mini-batches:  2000] loss: 4.996
# [Epoch number : 50, Mini-batches:  3000] loss: 5.149
# [Epoch number : 50, Mini-batches:  4000] loss: 5.107
# [Epoch number : 50, Mini-batches:  5000] loss: 5.190
# [Epoch number : 50, Mini-batches:  6000] loss: 5.118
#
# output predicted is : tensor([[ -8.8381,  -8.7032,  -7.0642,  ...,  -7.9572,  -7.7029,  -7.1958],
#         [ -7.6654,  -3.2643, -10.8052,  ..., -15.7336,  -4.6371,  -8.7850],
#         [ -3.0082,  -1.8176,  -3.6204,  ...,  -4.5863,  -1.0204,  -1.5956],
#         ...,
#         [-19.9207, -16.3299, -12.0442,  ..., -13.8444, -19.1244, -18.0839],
#         [ -4.9418,  -2.7238,  -5.7139,  ...,  -7.6464,  -7.0897,  -6.1808],
#         [ -9.1468, -10.8917,  -5.0845,  ...,  -1.5502, -12.1675,  -9.1395]])
# LeNet accuracy on 10000 images from test dataset: 67 %
#
# Finished Training

# %%
model_path = './cifar_model.pth'
torch.save(lenet.state_dict(), model_path)

# %%
# load test dataset images
d_iter = iter(testloader)
im, ground_truth = next(d_iter)

# print images and ground truth
imageshow(torchvision.utils.make_grid(im[:4]))
print('Label:      ', ' '.join('%5s' % classes[ground_truth[j]] for j in range(4)))

# load model
lenet_cached = LeNet()
lenet_cached.load_state_dict(torch.load(model_path))

# model inference
op = lenet_cached(im)

# print predictions
_, pred = torch.max(op, 1)

print('Prediction: ', ' '.join('%5s' % classes[pred[j]] for j in range(4)))
# Out:
# Label:         cat  ship  ship plane
# <ipython-input-38-bb0029f33402>:11: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   lenet_cached.load_state_dict(torch.load(model_path))
# Prediction:    cat   car  ship  ship

# %%
success = 0
counter = 0
with torch.no_grad():
    for data in testloader:
        im, ground_truth = data
        op = lenet_cached(im)
        _, pred = torch.max(op.data, 1)
        counter += ground_truth.size(0)
        success += (pred == ground_truth).sum().item()

print('Model accuracy on 10000 images from test dataset: %d %%' % (
    100 * success / counter))
# Out:
# Model accuracy on 10000 images from test dataset: 67 %

# %%
class_sucess = list(0. for i in range(10))
class_counter = list(0. for i in range(10))
with torch.no_grad():
    for data in testloader:
        im, ground_truth = data
        op = lenet_cached(im)
        _, pred = torch.max(op, 1)
        c = (pred == ground_truth).squeeze()
        for i in range(10000):
            ground_truth_curr = ground_truth[i]
            class_sucess[ground_truth_curr] += c[i].item()
            class_counter[ground_truth_curr] += 1


for i in range(10):
    print('Model accuracy for class %5s : %2d %%' % (
        classes[i], 100 * class_sucess[i] / class_counter[i]))
# Out:
# Model accuracy for class plane : 57 %
# Model accuracy for class   car : 86 %
# Model accuracy for class  bird : 55 %
# Model accuracy for class   cat : 56 %
# Model accuracy for class  deer : 70 %
# Model accuracy for class   dog : 53 %
# Model accuracy for class  frog : 77 %
# Model accuracy for class horse : 65 %
# Model accuracy for class  ship : 75 %
# Model accuracy for class truck : 78 %
